# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
x = np.linspace(0,10,30)
y = np.sin(x)

plt.scatter(x, y, marker='o')

# %%
x1 = np.linspace(0, 10, 100)
plt.plot(x1, np.sin(x1), label='sin(x)')  # 선 그래프

x2 = np.linspace(0, 10, 30)
y2 = np.linspace(0, 10, 30)
plt.plot(x2, y2, 'o', label='y = x (points)')  # 점으로만 표시

plt.legend()
plt.show()

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.2

# %%
rng = np.random.RandomState(42)
x = rng.randn(100)
y = rng.randn(100)
color = rng.randn(100)
sizes = 1000 * rng.randn(100)

plt.scatter(x,y,c=color, s=sizes, alpha=0.3, cmap="viridis")
# Out:
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\matplotlib\collections.py:999: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names
df = pd.DataFrame(X, columns=feature_names)
df['species'] = [target_names[i] for i in y]
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
plt.plot(iris.feature_names, means.loc[species], color=colors[i], label="A")
plt.scatter(x,y,c=color, s=sizes, alpha=0.3, cmap="viridis")

# %%
#sklearn에서 제공
iris = load_iris()
feat = iris.data.T #행열뒤집었다.
feat

plt.scatter(feat[0], feat[1], c=iris.target, s=100*feat[3], alpha=0.3) 
#종류별로 색으로 나눠 c=iris.target

# %%
iris.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
import numpy as np
rng = np.random.RandomState(42)

data = rng.randn(1000)
plt.hist(data)
# Out:
# (array([  4.,  22.,  96., 228., 272., 226., 104.,  38.,   9.,   1.]),
#  array([-3.24126734, -2.53186746, -1.82246757, -1.11306769, -0.40366781,
#          0.30573208,  1.01513196,  1.72453184,  2.43393172,  3.14333161,
#          3.85273149]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
iris = load_iris()
x = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names

df = pd.DataFrame(x, columns=feature_names)
df["species"] = [target_names[i] for i in y]

# %%
feature_names_kr = ["꽃받침 길이", "꽃받침 너비", "꽃잎 길이", "꽃잎 너비"]
target_names_kr = ["세토사", "버시컬러", "버지니카"]

# %%
colors = ["#FF6B63", "#4ECDC4", "#45B7D1"]
species_colors = {target_names[i]: colors[i] for i in range(3)}
